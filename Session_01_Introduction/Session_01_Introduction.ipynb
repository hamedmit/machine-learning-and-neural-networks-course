# %% [markdown]
# __Notebook Author__: Hamed Qazanfari
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hamedmit/machine-learning-and-neural-networks-course/blob/main/Session_01_Introduction/Session_01_Introduction.ipynb)
# [![Open In Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://raw.githubusercontent.com/hamedmit/machine-learning-and-neural-networks-course/main/Session_01_Introduction/Session_01_Introduction.ipynb)
#
# ---
#
# # 🎓 دوره یادگیری ماشین و شبکه‌های عصبی
# ## دانشگاه تربت حیدریه – UTH
# ## رشته: کاردانی ICT
# ## مدرس: حامد غضنفری
#
# ---
#
# # 1. مقدمه دوره (Introduction)
#
# دنیای فناوری به سمت سیستم‌های هوشمند حرکت می‌کند؛ از خودروهای خودران و جستجوی گوگل گرفته تا فیلترهای اینستاگرام، چت‌بات‌ها، سیستم‌های پیشنهادگر فیلم و حتی مدل‌های تولید تصویر. در مرکز تمام این سیستم‌ها دو مفهوم کلیدی وجود دارد:
#
# ### ✔ یادگیری ماشین (Machine Learning)
# ### ✔ شبکه‌های عصبی (Neural Networks)
#
# هدف این دوره این است که شما را از سطح پایه به‌گونه‌ای بالا ببریم که بتوانید **یک مدل ساده یادگیری ماشین یا شبکه عصبی را خودتان بسازید و اجرا کنید**؛ مثلاً:
#
# - تشخیص گربه/سگ از روی تصویر
# - پیش‌بینی قیمت (خانه، محصول، دلار…)
# - دسته‌بندی داده‌ها
# - خوشه‌بندی مشتریان یا کاربران
# - کاهش ابعاد و تحلیل داده
#
# و مهم‌تر از همه اینکه بتوانید **از Colab و GitHub** برای اجرای پروژه‌های واقعی استفاده کنید.
#
# ---
#
# # 2. مخاطبان دوره
#
# این دوره برای دانشجویان **کاردانی ICT** طراحی شده است.
#
# پیش‌نیازهای شما:
#
# - آشنایی متوسط با کامپیوتر
# - علاقه به هوش مصنوعی
# - توانایی اجرای مثال‌ها در Colab
# - کمی صبر و حوصله 😄
#
# در این دوره **کدنویسی از صفر یاد داده نمی‌شود**
# اما هر چیزی که لازم داشته باشید (NumPy, Pandas, Matplotlib) را قدم‌به‌قدم یاد خواهید گرفت.
#
# ---
#
# # 3. اهداف دوره
#
# در پایان این دوره شما باید بتوانید:
#
# ### 🎯 1. مفاهیم اصلی یادگیری ماشین را توضیح دهید
# - یادگیری نظارت‌شده
# - یادگیری بدون ناظر
# - شبکه‌های عصبی
# - گرادیان نزولی
# - کاهش ابعاد (PCA)
#
# ### 🎯 2. با Google Colab کار کنید
# - اجرای کد
# - آپلود دیتاست
# - اتصال به GitHub
# - ساخت گزارش و تحلیل
#
# ### 🎯 3. چندین مدل ML واقعی را بسازید
# - Linear Regression
# - KNN
# - K-Means
# - PCA
# - یک شبکه عصبی ساده
#
# ### 🎯 4. پروژه نهایی انجام دهید
# هر دانشجو باید یک **الگوریتم یادگیری ماشین** را انتخاب کند:
# - یک آموزش ویدیویی کوتاه بسازد
# - کد آن را توضیح دهد
# - با یک مثال واقعی اجرا کند
# - در کلاس ارائه دهد
#
# ---
#
# # 4. برنامه جلسات دوره
#
# در این دوره حدود **۱۳ جلسه** داریم:
#
# | جلسه | موضوع |
# |------|--------|
# | 1 | مقدمه و ساختار دوره |
# | 2 | آشنایی با Google Colab + Python مورد نیاز |
# | 3 | یادگیری نظارت‌شده + رگرسیون خطی |
# | 4 | الگوریتم KNN + تمرین عملی |
# | 5 | یادگیری بدون ناظر + K-Means |
# | 6 | کاهش ابعاد (PCA) + کاربردهای تصویری |
# | 7 | شبکه‌های عصبی: کارکرد نورون و وزن‌ها |
# | 8 | ساخت اولین شبکه عصبی |
# | 9 | کانولوشن و شبکه‌های CNN |
# | 10 | تشخیص تصویر با CNN |
# | 11 | پروژه‌های عملی و جمع‌بندی |
# | 12–13 | ارائه‌های دانشجویان و پروژه نهایی |
#
# ---
#
# # 5. نحوه ارزیابی
#
# | جزء | نمره |
# |-----|-------|
# | میان‌ترم | 4 |
# | پایان‌ترم | 7 |
# | ویدئو آموزشی | 2.5 |
# | ارائه کلاسی | 2.5 |
# | حضور و فعالیت | 3 |
# | کوییزها | 3 |
#
# | دو نمره هدیه در نظر گرفته شده است |
#
# ---
#
# # 6. ابزارهای دوره
#
# ### ✔ Google Colab
# اجرای تمام مثال‌ها
#
# ### ✔ Python
# کتابخانه‌های مورد نیاز:
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-Learn
#
# ### ✔ GitHub
# برای ذخیره نوت‌بوک‌ها و اشتراک‌گذاری آنها با دانشجویان
#
# ---
#
# # 7. نکته مهم برای دانشجویان
#
# برای یادگیری ML لازم نیست ریاضی خیلی قوی باشد.
# ما قدم‌به‌قدم جلو می‌رویم و مثال‌های زیاد خواهیم داشت.
#
# هدف ما این نیست که شما مقاله بنویسید،
# هدف این است که:
#
# ### ✔ بتوانید یک مدل واقعی ML را خودتان بسازید
# ### ✔ بتوانید آن را اجرا کنید
# ### ✔ بتوانید درباره آن ارائه دهید
#
# اگر سوالی داشتید — بپرسید.
# اگر گیج شدید — به من پیام بدهید.
# هیچ‌کس قرار نیست عقب بماند.
#
# ---
#
# # 8. شروع دوره
#
# در جلسه بعدی وارد Google Colab می‌شویم
# و اولین کد ML خودمان را اجرا می‌کنیم.
#
# **برو بریم. 🚀**
